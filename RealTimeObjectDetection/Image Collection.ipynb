# %% [markdown]
# # 1. Importing out dependencies

# %%
# Import opencv
import cv2 

# Import uuid
import uuid

# Import Operating System
import os

# Import time
import time

# !pip install split-folders

# %%
IMAGES_PATH = 'Tensorflow/workspace/images/collectedimages'

# %%
labels = ['nonsense']

# %%
for label in labels:
    # !mkdir {'Tensorflow/workspace/images/collectedimages/'+label}
    # for windows computers it'll be : 'Tensorflow\workspace\images\collectedimages\\'
    cap = cv2.VideoCapture(0)
    print('Collecting images for {}'.format(label))
    time.sleep(5)
    for imageNumber in range(5): 
        print('Collecting image {}'.format(imageNumber))
        print("capturing now!")
        ret, frame = cap.read()
        imgname = os.path.join(IMAGES_PATH,label,label+'.'+'{}.jpg'.format(str(uuid.uuid1())))
        cv2.imwrite(imgname, frame)
        cv2.imshow('frame', frame)
        time.sleep(2)

        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# mkdir: Tensorflow/workspace/images/collectedimages/nonsense: File exists
# ...
# capturing now!
# ...
# capturing now!
# ...
# capturing now!
# ...
# capturing now!
# ...
# capturing now!

# %%
cv2.destroyAllWindows()

# %%
import splitfolders
import os
import shutil

input_folder = 'Tensorflow/workspace/images/collectedimages/collectedimages/drink'
output_folder = 'Tensorflow/workspace/images/output_drink'
splitfolders.ratio(input_folder, output=output_folder, seed=1337, ratio=(0.8, 0, 0.2), group_prefix=None)


# Define the source folders
jpg_folder = 'Tensorflow/workspace/images/output_drink/test/drink_jpg'
xml_folder = 'Tensorflow/workspace/images/output_drink/test/drink_xml'

# Define the destination folder where you want to combine the contents
destination_folder = 'Tensorflow/workspace/images/test'

# Create the destination folder if it doesn't exist
if not os.path.exists(destination_folder):
    os.makedirs(destination_folder)

# Iterate over files in jpg_folder and copy them to the destination folder
for filename in os.listdir(jpg_folder):
    if filename.endswith('.jpg'):
        shutil.copy(os.path.join(jpg_folder, filename), destination_folder)

# Iterate over files in xml_folder and copy them to the destination folder
for filename in os.listdir(xml_folder):
    if filename.endswith('.xml'):
        shutil.copy(os.path.join(xml_folder, filename), destination_folder)

print("Contents of drink_jpg and drink_xml folders combined into", destination_folder)

# Define the source folders
jpg_folder = 'Tensorflow/workspace/images/output_drink/train/drink_jpg'
xml_folder = 'Tensorflow/workspace/images/output_drink/train/drink_xml'

# Define the destination folder where you want to combine the contents
destination_folder = 'Tensorflow/workspace/images/train'

# Create the destination folder if it doesn't exist
if not os.path.exists(destination_folder):
    os.makedirs(destination_folder)

# Iterate over files in jpg_folder and copy them to the destination folder
for filename in os.listdir(jpg_folder):
    if filename.endswith('.jpg'):
        shutil.copy(os.path.join(jpg_folder, filename), destination_folder)

# Iterate over files in xml_folder and copy them to the destination folder
for filename in os.listdir(xml_folder):
    if filename.endswith('.xml'):
        shutil.copy(os.path.join(xml_folder, filename), destination_folder)

print("Contents of drink_jpg and drink_xml folders combined into", destination_folder)

# %%
import splitfolders
import os
import shutil

# input_folder = 'Tensorflow/workspace/images/collectedimages/collectedimages/drink'
# output_folder = 'Tensorflow/workspace/images/output'
# splitfolders.ratio(input_folder, output=output_folder, seed=1337, ratio=(0.8, 0, 0.2), group_prefix=None)

input_folder = 'Tensorflow/workspace/images/collectedimages/collectedimages/eat'
output_folder = 'Tensorflow/workspace/images/output_eat'
splitfolders.ratio(input_folder, output=output_folder, seed=1337, ratio=(0.8, 0, 0.2), group_prefix=None)



# Define the source folders
jpg_folder = 'Tensorflow/workspace/images/output_eat/test/eat_jpg'
xml_folder = 'Tensorflow/workspace/images/output_eat/test/eat_xml'

# Define the destination folder where you want to combine the contents
destination_folder = 'Tensorflow/workspace/images/test'

# Create the destination folder if it doesn't exist
if not os.path.exists(destination_folder):
    os.makedirs(destination_folder)

# Iterate over files in jpg_folder and copy them to the destination folder
for filename in os.listdir(jpg_folder):
    if filename.endswith('.jpg'):
        shutil.copy(os.path.join(jpg_folder, filename), destination_folder)

# Iterate over files in xml_folder and copy them to the destination folder
for filename in os.listdir(xml_folder):
    if filename.endswith('.xml'):
        shutil.copy(os.path.join(xml_folder, filename), destination_folder)

print("Contents of eat_jpg and eat_xml folders combined into", destination_folder)

# Define the source folders
jpg_folder = 'Tensorflow/workspace/images/output_eat/train/eat_jpg'
xml_folder = 'Tensorflow/workspace/images/output_eat/train/eat_xml'

# Define the destination folder where you want to combine the contents
destination_folder = 'Tensorflow/workspace/images/train'

# Create the destination folder if it doesn't exist
if not os.path.exists(destination_folder):
    os.makedirs(destination_folder)

# Iterate over files in jpg_folder and copy them to the destination folder
for filename in os.listdir(jpg_folder):
    if filename.endswith('.jpg'):
        shutil.copy(os.path.join(jpg_folder, filename), destination_folder)

# Iterate over files in xml_folder and copy them to the destination folder
for filename in os.listdir(xml_folder):
    if filename.endswith('.xml'):
        shutil.copy(os.path.join(xml_folder, filename), destination_folder)

print("Contents of eat_jpg and eat_xml folders combined into", destination_folder)

# %%
import splitfolders
import os
import shutil

# input_folder = 'Tensorflow/workspace/images/collectedimages/collectedimages/drink'
# output_folder = 'Tensorflow/workspace/images/output'
# splitfolders.ratio(input_folder, output=output_folder, seed=1337, ratio=(0.8, 0, 0.2), group_prefix=None)

input_folder = 'Tensorflow/workspace/images/collectedimages/collectedimages/finish'
output_folder = 'Tensorflow/workspace/images/output_finish'
splitfolders.ratio(input_folder, output=output_folder, seed=1337, ratio=(0.8, 0, 0.2), group_prefix=None)



# Define the source folders
jpg_folder = 'Tensorflow/workspace/images/output_finish/test/finish_jpg'
xml_folder = 'Tensorflow/workspace/images/output_finish/test/finish_xml'

# Define the destination folder where you want to combine the contents
destination_folder = 'Tensorflow/workspace/images/test'

# Create the destination folder if it doesn't exist
if not os.path.exists(destination_folder):
    os.makedirs(destination_folder)

# Iterate over files in jpg_folder and copy them to the destination folder
for filename in os.listdir(jpg_folder):
    if filename.endswith('.jpg'):
        shutil.copy(os.path.join(jpg_folder, filename), destination_folder)

# Iterate over files in xml_folder and copy them to the destination folder
for filename in os.listdir(xml_folder):
    if filename.endswith('.xml'):
        shutil.copy(os.path.join(xml_folder, filename), destination_folder)

print("Contents of finish_jpg and finish_xml folders combined into", destination_folder)

# Define the source folders
jpg_folder = 'Tensorflow/workspace/images/output_finish/train/finish_jpg'
xml_folder = 'Tensorflow/workspace/images/output_finish/train/finish_xml'

# Define the destination folder where you want to combine the contents
destination_folder = 'Tensorflow/workspace/images/train'

# Create the destination folder if it doesn't exist
if not os.path.exists(destination_folder):
    os.makedirs(destination_folder)

# Iterate over files in jpg_folder and copy them to the destination folder
for filename in os.listdir(jpg_folder):
    if filename.endswith('.jpg'):
        shutil.copy(os.path.join(jpg_folder, filename), destination_folder)

# Iterate over files in xml_folder and copy them to the destination folder
for filename in os.listdir(xml_folder):
    if filename.endswith('.xml'):
        shutil.copy(os.path.join(xml_folder, filename), destination_folder)

print("Contents of finish_jpg and finish_xml folders combined into", destination_folder)

# %%
import splitfolders
import os
import shutil

# input_folder = 'Tensorflow/workspace/images/collectedimages/collectedimages/drink'
# output_folder = 'Tensorflow/workspace/images/output'
# splitfolders.ratio(input_folder, output=output_folder, seed=1337, ratio=(0.8, 0, 0.2), group_prefix=None)

input_folder = 'Tensorflow/workspace/images/collectedimages/collectedimages/give'
output_folder = 'Tensorflow/workspace/images/output_give'
splitfolders.ratio(input_folder, output=output_folder, seed=1337, ratio=(0.8, 0, 0.2), group_prefix=None)



# Define the source folders
jpg_folder = 'Tensorflow/workspace/images/output_give/test/give_jpg'
xml_folder = 'Tensorflow/workspace/images/output_give/test/give_xml'

# Define the destination folder where you want to combine the contents
destination_folder = 'Tensorflow/workspace/images/test'

# Create the destination folder if it doesn't exist
if not os.path.exists(destination_folder):
    os.makedirs(destination_folder)

# Iterate over files in jpg_folder and copy them to the destination folder
for filename in os.listdir(jpg_folder):
    if filename.endswith('.jpg'):
        shutil.copy(os.path.join(jpg_folder, filename), destination_folder)

# Iterate over files in xml_folder and copy them to the destination folder
for filename in os.listdir(xml_folder):
    if filename.endswith('.xml'):
        shutil.copy(os.path.join(xml_folder, filename), destination_folder)

print("Contents of give_jpg and give_xml folders combined into", destination_folder)

# Define the source folders
jpg_folder = 'Tensorflow/workspace/images/output_give/train/give_jpg'
xml_folder = 'Tensorflow/workspace/images/output_give/train/give_xml'

# Define the destination folder where you want to combine the contents
destination_folder = 'Tensorflow/workspace/images/train'

# Create the destination folder if it doesn't exist
if not os.path.exists(destination_folder):
    os.makedirs(destination_folder)

# Iterate over files in jpg_folder and copy them to the destination folder
for filename in os.listdir(jpg_folder):
    if filename.endswith('.jpg'):
        shutil.copy(os.path.join(jpg_folder, filename), destination_folder)

# Iterate over files in xml_folder and copy them to the destination folder
for filename in os.listdir(xml_folder):
    if filename.endswith('.xml'):
        shutil.copy(os.path.join(xml_folder, filename), destination_folder)

print("Contents of give_jpg and give_xml folders combined into", destination_folder)

# %%
import matplotlib.pyplot as plt

class_names = ["drink", "eat", "finish", "give"]
class_counts = [50, 50, 50, 50]  # Number of images for each class

# Plotting the bar chart
plt.figure(figsize=(8, 6))
plt.bar(class_names, class_counts, color=['blue', 'green', 'orange', 'red'])
plt.xlabel('Classes')
plt.ylabel('Number of Images')
plt.title('Class Balance')
plt.grid(True, axis='y', linestyle='--', alpha=0.7)
plt.show()
